# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import glob
import joblib
from xgboost import plot_importance
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

preds = '../outputs/predictions/xgboost_optuna_vals.csv'
test = '../data/processed/processed_all.csv'

df = pd.read_csv(test)
supp = pd.read_csv(preds)

df = df[df['season'] == 2023]
df = df[(df['down'] == 3) | (df['down'] == 4)]
df["log_ydstogo"] = np.log1p(df["ydstogo"])
df["log_yardline_100"] = np.log1p(df["yardline_100"])

data = df.merge(supp, left_index=True, right_on="orig_index").drop(columns=["Unnamed: 0", "orig_index"])

# %%
xgb_model = joblib.load('../models/xgboost_optuna.joblib')

# %%
preproc = xgb_model.named_steps["preproc"]
model = xgb_model.named_steps["model"]

feature_names = preproc.get_feature_names_out()
importances = model.feature_importances_

df_xgb = (
    pd.DataFrame({
        "feature": feature_names,
        "importance": importances
    })
    .sort_values("importance", ascending=False)
)

df_xgb
# Out:
#                                  feature  importance
# 4                     remainder__ydstogo    0.149213
# 2    cat__offense_formation_UNDER_CENTER    0.062938
# 1         cat__offense_formation_SHOTGUN    0.040432
# 3                        remainder__down    0.031186
# 13                         remainder__DB    0.028048
# 9                          remainder__WR    0.027290
# 5                remainder__yardline_100    0.026104
# 18                        remainder__qtr    0.026078
# 17                 remainder__total_line    0.025280
# 20                        remainder__QB1    0.024302
# 6            remainder__defenders_in_box    0.024272
# 24                        remainder__WR1    0.024022
# 26                        remainder__WR3    0.023673
# 32     remainder__conversion_rate_season    0.023510
# 19  remainder__quarter_seconds_remaining    0.023481
# 27                        remainder__TE1    0.023439
# 31             remainder__pass_run_ratio    0.023307
# 34        remainder__success_rate_season    0.023121
# 14                       remainder__home    0.023040
# 30          remainder__rush_yards_season    0.022852
# 16                     remainder__spread    0.022831
# 28                        remainder__TE2    0.022788
# 15         remainder__score_differential    0.022726
# 29          remainder__pass_yards_season    0.022714
# 33           remainder__sack_rate_season    0.022468
# 8                          remainder__TE    0.022466
# 25                        remainder__WR2    0.022374
# 12                         remainder__LB    0.022315
# 0          cat__offense_formation_PISTOL    0.022254
# 11                         remainder__DL    0.022099
# 22                        remainder__RB1    0.022087
# 23                        remainder__RB2    0.022077
# 10                         remainder__OL    0.019606
# 7                          remainder__RB    0.019042
# 21                        remainder__QB2    0.016568

# %%
rf_model = joblib.load('../models/random_forest_optuna.joblib')

rf = rf_model.named_steps["model"]
rf_importances = rf.feature_importances_
rf_features = rf_model.named_steps["preproc"].get_feature_names_out()

df_rf = pd.DataFrame({
    "feature": rf_features,
    "importance": rf_importances
}).sort_values("importance", ascending=False)

display(df_rf)
# Out:
#                                  feature  importance
# 4                     remainder__ydstogo    0.346990
# 19  remainder__quarter_seconds_remaining    0.071807
# 5                remainder__yardline_100    0.067208
# 17                 remainder__total_line    0.042687
# 15         remainder__score_differential    0.039319
# 16                     remainder__spread    0.038510
# 20                        remainder__QB1    0.030203
# 27                        remainder__TE1    0.030072
# 31             remainder__pass_run_ratio    0.027460
# 22                        remainder__RB1    0.026726
# 33           remainder__sack_rate_season    0.026515
# 32     remainder__conversion_rate_season    0.025887
# 24                        remainder__WR1    0.025066
# 30          remainder__rush_yards_season    0.025063
# 34        remainder__success_rate_season    0.024459
# 25                        remainder__WR2    0.024304
# 29          remainder__pass_yards_season    0.023629
# 26                        remainder__WR3    0.021009
# 6            remainder__defenders_in_box    0.013438
# 18                        remainder__qtr    0.012746
# 28                        remainder__TE2    0.008964
# 12                         remainder__LB    0.008830
# 11                         remainder__DL    0.008728
# 13                         remainder__DB    0.005882
# 14                       remainder__home    0.004731
# 23                        remainder__RB2    0.004217
# 2    cat__offense_formation_UNDER_CENTER    0.003519
# 9                          remainder__WR    0.002909
# 3                        remainder__down    0.002738
# 1         cat__offense_formation_SHOTGUN    0.002091
# 8                          remainder__TE    0.001603
# 7                          remainder__RB    0.001354
# 10                         remainder__OL    0.001036
# 0          cat__offense_formation_PISTOL    0.000300
# 21                        remainder__QB2    0.000000

# %%
log_model = joblib.load('../models/logistic_optuna.joblib')

logreg = log_model.named_steps["model"]
coef = logreg.coef_[0]

features = log_model.named_steps["preproc"].get_feature_names_out()

df_log = pd.DataFrame({
    "feature": features,
    "coef": coef,
    "abs_coef": np.abs(coef)
}).sort_values("abs_coef", ascending=False)

display(df_log)
# Out:
#                                 feature      coef  abs_coef
# 0                          num__ydstogo -0.509458  0.509458
# 22  cat__offense_formation_UNDER_CENTER  0.149836  0.149836
# 21       cat__offense_formation_SHOTGUN -0.092909  0.092909
# 4                       num__total_line  0.083432  0.083432
# 5                              num__QB1  0.064479  0.064479
# 1                     num__yardline_100  0.048999  0.048999
# 11                             num__WR3  0.036099  0.036099
# 8                              num__RB2  0.033014  0.033014
# 13                             num__TE2  0.032111  0.032111
# 15               num__pass_yards_season -0.026466  0.026466
# 17          num__conversion_rate_season  0.024665  0.024665
# 12                             num__TE1  0.024404  0.024404
# 20        cat__offense_formation_PISTOL -0.021699  0.021699
# 2               num__score_differential -0.020284  0.020284
# 19             num__success_rate_season  0.018640  0.018640
# 10                             num__WR2  0.012742  0.012742
# 18                num__sack_rate_season  0.009633  0.009633
# 3                           num__spread  0.008684  0.008684
# 7                              num__RB1  0.006378  0.006378
# 9                              num__WR1  0.006340  0.006340
# 16               num__rush_yards_season  0.003204  0.003204
# 6                              num__QB2 -0.001714  0.001714
# 14                  num__pass_run_ratio  0.000844  0.000844

# %%
df_xgb = df_xgb[['feature','importance']].rename(columns={'importance':'xgb'})
df_rf  = df_rf[['feature','importance']].rename(columns={'importance':'rf'})
df_log = df_log[['feature','abs_coef']].rename(columns={'abs_coef':'logreg'})

# %%
df_all = (
    df_xgb
    .merge(df_rf, on='feature', how='outer')
    .merge(df_log, on='feature', how='outer')
)

# %%
df_all = df_all.fillna(0)

# %%
df_all = df_all.sort_values('rf', ascending=False)

# %%
display(df_all)
# Out:
#                                  feature       xgb        rf    logreg
# 54                    remainder__ydstogo  0.149213  0.346990  0.000000
# 46  remainder__quarter_seconds_remaining  0.023481  0.071807  0.000000
# 53               remainder__yardline_100  0.026104  0.067208  0.000000
# 52                 remainder__total_line  0.025280  0.042687  0.000000
# 49         remainder__score_differential  0.022726  0.039319  0.000000
# 50                     remainder__spread  0.022831  0.038510  0.000000
# 27                        remainder__QB1  0.024302  0.030203  0.000000
# 33                        remainder__TE1  0.023439  0.030072  0.000000
# 43             remainder__pass_run_ratio  0.023307  0.027460  0.000000
# 30                        remainder__RB1  0.022087  0.026726  0.000000
# 48           remainder__sack_rate_season  0.022468  0.026515  0.000000
# 39     remainder__conversion_rate_season  0.023510  0.025887  0.000000
# 36                        remainder__WR1  0.024022  0.025066  0.000000
# 47          remainder__rush_yards_season  0.022852  0.025063  0.000000
# 51        remainder__success_rate_season  0.023121  0.024459  0.000000
# 37                        remainder__WR2  0.022374  0.024304  0.000000
# 44          remainder__pass_yards_season  0.022714  0.023629  0.000000
# 38                        remainder__WR3  0.023673  0.021009  0.000000
# 40           remainder__defenders_in_box  0.024272  0.013438  0.000000
# 45                        remainder__qtr  0.026078  0.012746  0.000000
# 34                        remainder__TE2  0.022788  0.008964  0.000000
# 25                         remainder__LB  0.022315  0.008830  0.000000
# 24                         remainder__DL  0.022099  0.008728  0.000000
# 23                         remainder__DB  0.028048  0.005882  0.000000
# 42                       remainder__home  0.023040  0.004731  0.000000
# 31                        remainder__RB2  0.022077  0.004217  0.000000
# 2    cat__offense_formation_UNDER_CENTER  0.062938  0.003519  0.149836
# 35                         remainder__WR  0.027290  0.002909  0.000000
# 41                       remainder__down  0.031186  0.002738  0.000000
# 1         cat__offense_formation_SHOTGUN  0.040432  0.002091  0.092909
# 32                         remainder__TE  0.022466  0.001603  0.000000
# 29                         remainder__RB  0.019042  0.001354  0.000000
# 26                         remainder__OL  0.019606  0.001036  0.000000
# 0          cat__offense_formation_PISTOL  0.022254  0.000300  0.021699
# 20                       num__total_line  0.000000  0.000000  0.083432
# 11                              num__WR3  0.000000  0.000000  0.036099
# 8                               num__TE2  0.000000  0.000000  0.032111
# 7                               num__TE1  0.000000  0.000000  0.024404
# 9                               num__WR1  0.000000  0.000000  0.006340
# 22                          num__ydstogo  0.000000  0.000000  0.509458
# 21                     num__yardline_100  0.000000  0.000000  0.048999
# 6                               num__RB2  0.000000  0.000000  0.033014
# 19              num__success_rate_season  0.000000  0.000000  0.018640
# 18                           num__spread  0.000000  0.000000  0.008684
# 12           num__conversion_rate_season  0.000000  0.000000  0.024665
# 17               num__score_differential  0.000000  0.000000  0.020284
# 16                 num__sack_rate_season  0.000000  0.000000  0.009633
# 15                num__rush_yards_season  0.000000  0.000000  0.003204
# 14                num__pass_yards_season  0.000000  0.000000  0.026466
# 13                   num__pass_run_ratio  0.000000  0.000000  0.000844
# 4                               num__QB2  0.000000  0.000000  0.001714
# 3                               num__QB1  0.000000  0.000000  0.064479
# 5                               num__RB1  0.000000  0.000000  0.006378
# 28                        remainder__QB2  0.016568  0.000000  0.000000
# 10                              num__WR2  0.000000  0.000000  0.012742

# %%
pass_mask = data['play_type'] == 'pass'

precision_pass = precision_score(
    data[pass_mask]['y_true'],
    data[pass_mask]['y_pred']
)

recall_pass = recall_score(
    data[pass_mask]['y_true'],
    data[pass_mask]['y_pred']
)

precision_pass, recall_pass
# Out:
# (0.5049283154121864, 0.47552742616033755)

# %%
pass_mask = data['play_type'] == 'run'

precision_pass = precision_score(
    data[pass_mask]['y_true'],
    data[pass_mask]['y_pred']
)

recall_pass = recall_score(
    data[pass_mask]['y_true'],
    data[pass_mask]['y_pred']
)

precision_pass, recall_pass
# Out:
# (0.6540880503144654, 0.8041237113402062)
